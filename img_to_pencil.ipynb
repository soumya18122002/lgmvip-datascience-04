# %%
#IMPORT LIBRARIES
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

# plt.imshow(img)
# plt.show()
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("Sheep Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")

image = mpimg.imread("C:\\Users\\dawns\\OneDrive\\Desktop\\Let's Grow More Projects\\Image to Pencillic Sketch\\little-girl-7868485.jpg")
plt.imshow(image)
plt.show()

# %%
#Color value just for own sake
import cv2
img=cv2.imread("C:\\Users\\dawns\\OneDrive\\Desktop\\Let's Grow More Projects\\Image to Pencillic Sketch\\little-girl-7868485.jpg",0)
print('Minimum color range',img.min())
print('Maximum color range',img.max())
# Out:
# Minimum color range 33
# Maximum color range 255

# %%
#Converting image to greyscale
plt.imshow(img,cmap='gray')
plt.title('Black and white imege')
plt.show()

# %%
#Inverting the image
inv=255-img
plt.title('Inverted imege')
plt.imshow(inv,cmap='gray')
plt.show()

# %%
#Applying Gaussian blur to smooth out the image
gblur=cv2.GaussianBlur(inv,ksize=(21,21),sigmaX=0,sigmaY=0)
plt.title('Imege after Gaussian blur applied')
plt.imshow(gblur,cmap='gray')
plt.show()

# %%
#Dodging and burninG
dodge= lambda image,mask: cv2.divide(image,255-mask,scale=256)
blended=dodge(img,gblur)
plt.title('Pencil sketch of image')
plt.imshow(blended,cmap='gray')
plt.show()
